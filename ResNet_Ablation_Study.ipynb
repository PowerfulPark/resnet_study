# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds

import numpy as np
import matplotlib.pyplot as plt

# %%
def block(input_layer,
          channel_size,
          num_block,
          is_50 = False,
          first_block = False
          ):

    x = input_layer

    prev_layer_50 = x

    #블록 수만큼 회전
    for i in range(num_block):

        #첫 번째 블록의 첫 번째 CNN에서만 strides를 적용하기 위함.
        if first_block and i == 0:
            strides = (2,2)
        else:
            strides = (1,1)

        # 50일 경우 1*1 레이어 활성화
        if is_50 :
            x = keras.layers.Conv2D(filters = channel_size, kernel_size = (1,1), padding = 'same', strides=strides)(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)

        # 50일 경우 3*3 레이어 1회
            x = keras.layers.Conv2D(filters = channel_size, kernel_size = (3,3), padding = 'same')(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)

        # 50일 경우 1*1 레이어 1회
            x = keras.layers.Conv2D(filters = channel_size*4, kernel_size = (1,1), padding = 'same')(x)
            x = keras.layers.BatchNormalization()(x)
            if num_block-1 == i:
                #prev_layer_50의 채널 수를 맞춰 주기 위해 필터를 조절합니다.
                prev_layer_50 = keras.layers.Conv2D(filters=channel_size*4, kernel_size=(1,1), padding='same', strides=strides)(prev_layer_50)
                x = keras.layers.Add()([x, prev_layer_50])
                x = keras.layers.Activation('relu')(x)
            else:
                x = keras.layers.Activation('relu')(x)

        # 50이 아닐 경우 3*3 레이어 2회
        else :
            prev_layer_not50 = x

            x = keras.layers.Conv2D(filters = channel_size, kernel_size = (3,3), padding = 'same', strides=strides)(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)
            x = keras.layers.Conv2D(filters = channel_size, kernel_size = (3,3), padding = 'same')(x)
            x = keras.layers.BatchNormalization()(x)

            if num_block-1 == i:
                prev_layer_not50 = keras.layers.Conv2D(filters = channel_size, kernel_size = (1,1), padding = 'same')(prev_layer_not50)
                x = keras.layers.Add()([x, prev_layer_not50])
                x = keras.layers.Activation('relu')(x)

    return x

# %%
def build_resnet(input_shape,
                 num_channel_list = [64, 128, 256, 512],
                 num_block_list = [3, 4, 6, 3],
                 is_50 = False,
                 num_classes=1
                 ):

    input_layer = keras.layers.Input(input_shape)
    output = input_layer

    output = keras.layers.Conv2D(filters = 64, kernel_size = (7,7), padding = 'same', name = "conv1", strides = (2,2))(output)
    output = keras.layers.BatchNormalization()(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.MaxPooling2D(pool_size = (3,3), strides=(2,2))(output)

    for i, (num_cnn, num_block) in enumerate(zip(num_channel_list, num_block_list)):
        first_block = (i==0)
        output = block(output, channel_size = num_cnn, num_block = num_block, is_50 = is_50, first_block=first_block)

    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(1000, activation='relu', name='fc1')(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)

    model = keras.Model(
        inputs=input_layer,
        outputs=output
    )
    return model

# %%
resnet_34 = build_resnet(input_shape=(32,32,3), is_50 = False)

resnet_34.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv1 (Conv2D)              (None, 16, 16, 64)           9472      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 64)           256       ['conv1[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 16, 16, 64)           0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 7, 7, 64)             0         ['activation[0][0]']
#  D)
#
#  conv2d (Conv2D)             (None, 4, 4, 64)             36928     ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 4, 4, 64)             256       ['conv2d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 64)             0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 64)             36928     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 4, 4, 64)             256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)             36928     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 4, 4, 64)             256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 4, 4, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 64)             36928     ['activation_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 4, 4, 64)             256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)             36928     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  batch_normalization_5 (Bat  (None, 4, 4, 64)             256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 4, 4, 64)             0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)             36928     ['activation_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 4, 4, 64)             256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 64)             4160      ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 4, 4, 64)             0         ['batch_normalization_6[0][0]'
#                                                                     , 'conv2d_6[0][0]']
#
#  activation_4 (Activation)   (None, 4, 4, 64)             0         ['add[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 128)            73856     ['activation_4[0][0]']
#
#  batch_normalization_7 (Bat  (None, 4, 4, 128)            512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 4, 4, 128)            0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 128)            147584    ['activation_5[0][0]']
#
#  batch_normalization_8 (Bat  (None, 4, 4, 128)            512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 128)            147584    ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 4, 4, 128)            512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 4, 4, 128)            0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 128)            147584    ['activation_6[0][0]']
#
#  batch_normalization_10 (Ba  (None, 4, 4, 128)            512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 128)            147584    ['batch_normalization_10[0][0]
#                                                                     ']
#
#  batch_normalization_11 (Ba  (None, 4, 4, 128)            512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 4, 4, 128)            0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 4, 4, 128)            147584    ['activation_7[0][0]']
#
#  batch_normalization_12 (Ba  (None, 4, 4, 128)            512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 128)            147584    ['batch_normalization_12[0][0]
#                                                                     ']
#
#  batch_normalization_13 (Ba  (None, 4, 4, 128)            512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 4, 4, 128)            0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 128)            147584    ['activation_8[0][0]']
#
#  batch_normalization_14 (Ba  (None, 4, 4, 128)            512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 128)            16512     ['batch_normalization_12[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, 4, 4, 128)            0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'conv2d_15[0][0]']
#
#  activation_9 (Activation)   (None, 4, 4, 128)            0         ['add_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 4, 4, 256)            295168    ['activation_9[0][0]']
#
#  batch_normalization_15 (Ba  (None, 4, 4, 256)            1024      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_10[0][0]']
#
#  batch_normalization_16 (Ba  (None, 4, 4, 256)            1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 4, 4, 256)            590080    ['batch_normalization_16[0][0]
#                                                                     ']
#
#  batch_normalization_17 (Ba  (None, 4, 4, 256)            1024      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_11[0][0]']
#
#  batch_normalization_18 (Ba  (None, 4, 4, 256)            1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 4, 4, 256)            590080    ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_19 (Ba  (None, 4, 4, 256)            1024      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_12[0][0]']
#
#  batch_normalization_20 (Ba  (None, 4, 4, 256)            1024      ['conv2d_21[0][0]']
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 4, 4, 256)            590080    ['batch_normalization_20[0][0]
#                                                                     ']
#
#  batch_normalization_21 (Ba  (None, 4, 4, 256)            1024      ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_13[0][0]']
#
#  batch_normalization_22 (Ba  (None, 4, 4, 256)            1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 256)            590080    ['batch_normalization_22[0][0]
#                                                                     ']
#
#  batch_normalization_23 (Ba  (None, 4, 4, 256)            1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_14[0][0]']
#
#  batch_normalization_24 (Ba  (None, 4, 4, 256)            1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 256)            590080    ['batch_normalization_24[0][0]
#                                                                     ']
#
#  batch_normalization_25 (Ba  (None, 4, 4, 256)            1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_15[0][0]']
#
#  batch_normalization_26 (Ba  (None, 4, 4, 256)            1024      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  conv2d_28 (Conv2D)          (None, 4, 4, 256)            65792     ['batch_normalization_24[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 4, 4, 256)            0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      'conv2d_28[0][0]']
#
#  activation_16 (Activation)  (None, 4, 4, 256)            0         ['add_2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 4, 4, 512)            1180160   ['activation_16[0][0]']
#
#  batch_normalization_27 (Ba  (None, 4, 4, 512)            2048      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_17[0][0]']
#
#  batch_normalization_28 (Ba  (None, 4, 4, 512)            2048      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  conv2d_31 (Conv2D)          (None, 4, 4, 512)            2359808   ['batch_normalization_28[0][0]
#                                                                     ']
#
#  batch_normalization_29 (Ba  (None, 4, 4, 512)            2048      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_18[0][0]']
#
#  batch_normalization_30 (Ba  (None, 4, 4, 512)            2048      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  conv2d_33 (Conv2D)          (None, 4, 4, 512)            2359808   ['batch_normalization_30[0][0]
#                                                                     ']
#
#  batch_normalization_31 (Ba  (None, 4, 4, 512)            2048      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 4, 4, 512)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 4, 4, 512)            2359808   ['activation_19[0][0]']
#
#  batch_normalization_32 (Ba  (None, 4, 4, 512)            2048      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  conv2d_35 (Conv2D)          (None, 4, 4, 512)            262656    ['batch_normalization_30[0][0]
#                                                                     ']
#
#  add_3 (Add)                 (None, 4, 4, 512)            0         ['batch_normalization_32[0][0]
#                                                                     ',
#                                                                      'conv2d_35[0][0]']
#
#  activation_20 (Activation)  (None, 4, 4, 512)            0         ['add_3[0][0]']
#
#  flatten (Flatten)           (None, 8192)                 0         ['activation_20[0][0]']
#
#  fc1 (Dense)                 (None, 1000)                 8193000   ['flatten[0][0]']
#
#  predictions (Dense)         (None, 1)                    1001      ['fc1[0][0]']
#
# ==================================================================================================
# Total params: 29676817 (113.21 MB)
# Trainable params: 29661585 (113.15 MB)
# Non-trainable params: 15232 (59.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# PlainNet 제작

# %%
def plain_block(input_layer,
          channel_size,
          num_block,
          is_50 = False
          ):

    x = input_layer

    #블록 수만큼 회전
    for i in range(num_block):

        # 50일 경우 1*1 레이어 활성화
        if is_50 :
            x = keras.layers.Conv2D(filters = channel_size, kernel_size = (1,1), padding = 'same')(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)

        # 50일 경우 3*3 레이어 1회
            x = keras.layers.Conv2D(filters = channel_size, kernel_size = (3,3), padding = 'same')(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)

        # 50일 경우 1*1 레이어 1회
            x = keras.layers.Conv2D(filters = channel_size*4, kernel_size = (1,1), padding = 'same')(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation('relu')(x)

        # 50이 아닐 경우 3*3 레이어 2회
        else :
            for j in range(2):
                x = keras.layers.Conv2D(filters = channel_size, kernel_size = (3,3), padding = 'same')(x)
                x = keras.layers.BatchNormalization()(x)
                x = keras.layers.Activation('relu')(x)

    return x

# %%
def build_plainnet(input_shape,
                 num_channel_list = [64, 128, 256, 512],
                 num_block_list = [3, 4, 6, 3],
                 is_50 = False,
                 num_classes=1
                 ):

    input_layer = keras.layers.Input(input_shape)
    output = input_layer

    output = keras.layers.Conv2D(filters = 64, kernel_size = (7,7), padding = 'same', name = "conv1", strides = (2,2))(output)
    output = keras.layers.BatchNormalization()(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.MaxPooling2D(pool_size = (3,3), strides=(2,2))(output)

    for i, (num_cnn, num_block) in enumerate(zip(num_channel_list, num_block_list)):
        output = plain_block(output, channel_size = num_cnn, num_block = num_block, is_50 = is_50)
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(1000, activation='relu', name='fc1')(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)

    model = keras.Model(
        inputs=input_layer,
        outputs=output
    )
    return model
